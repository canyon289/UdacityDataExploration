# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("https://dataminingproject.googlecode.com/svn-history/r44/DataMiningApp/datasets/Iris/iris.csv")

# %%
fig = plt.figure(figsize = (14, 6))
ax = fig.add_subplot(111)
ax.set_xlabel('common xlabel')
ax.set_ylabel('common ylabel')
df[["Sepal Length", "Species"]].hist(by = "Species", ax=ax)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D6E0358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D854DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D576EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D5C6668>]], dtype=object)
